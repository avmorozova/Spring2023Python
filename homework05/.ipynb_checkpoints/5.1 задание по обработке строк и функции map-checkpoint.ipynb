# %% [markdown]
# # Обработка строк и функций map

# %% [markdown]
# ## Построение графиков

# %%
#import matplotlib
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#       --------------------------------------- 0.1/7.6 MB 2.4 MB/s eta 0:00:04
#      - -------------------------------------- 0.3/7.6 MB 3.5 MB/s eta 0:00:03
#      --- ------------------------------------ 0.6/7.6 MB 4.4 MB/s eta 0:00:02
#      --- ------------------------------------ 0.7/7.6 MB 4.5 MB/s eta 0:00:02
#      ------ --------------------------------- 1.2/7.6 MB 5.1 MB/s eta 0:00:02
#      --------- ------------------------------ 1.9/7.6 MB 6.2 MB/s eta 0:00:01
#      ------------ --------------------------- 2.3/7.6 MB 6.6 MB/s eta 0:00:01
#      ------------- -------------------------- 2.6/7.6 MB 7.0 MB/s eta 0:00:01
#      ----------------- ---------------------- 3.3/7.6 MB 7.5 MB/s eta 0:00:01
#      ------------------- -------------------- 3.7/7.6 MB 7.7 MB/s eta 0:00:01
#      ------------------- -------------------- 3.8/7.6 MB 7.6 MB/s eta 0:00:01
#      -------------------- ------------------- 4.0/7.6 MB 6.6 MB/s eta 0:00:01
#      ---------------------- ----------------- 4.4/7.6 MB 6.8 MB/s eta 0:00:01
#      ------------------------ --------------- 4.7/7.6 MB 6.8 MB/s eta 0:00:01
#      ------------------------- -------------- 4.9/7.6 MB 6.7 MB/s eta 0:00:01
#      --------------------------- ------------ 5.2/7.6 MB 6.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 5.6/7.6 MB 6.8 MB/s eta 0:00:01
#      ------------------------------- -------- 5.9/7.6 MB 6.8 MB/s eta 0:00:01
#      -------------------------------- ------- 6.2/7.6 MB 6.7 MB/s eta 0:00:01
#      --------------------------------- ------ 6.3/7.6 MB 6.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 6.8/7.6 MB 6.5 MB/s eta 0:00:01
#      ------------------------------------ --- 7.0/7.6 MB 6.6 MB/s eta 0:00:01
#      -------------------------------------- - 7.3/7.6 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 6.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp310-cp310-win_amd64.whl (162 kB)
#      ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#      -------------------------------------- 163.0/163.0 kB 9.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 0.0/55.3 kB ? eta -:--:--
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---- ----------------------------------- 0.3/2.5 MB 8.6 MB/s eta 0:00:01
#      ------- -------------------------------- 0.5/2.5 MB 6.3 MB/s eta 0:00:01
#      ------------- -------------------------- 0.8/2.5 MB 5.7 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.1/2.5 MB 5.7 MB/s eta 0:00:01
#      --------------------- ------------------ 1.4/2.5 MB 5.7 MB/s eta 0:00:01
#      ------------------------- -------------- 1.6/2.5 MB 5.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.9/2.5 MB 5.9 MB/s eta 0:00:01
#      -------------------------------- ------- 2.0/2.5 MB 5.6 MB/s eta 0:00:01
#      ------------------------------------- -- 2.4/2.5 MB 5.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\python310\lib\site-packages (from matplotlib) (1.24.3)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ------------ --------------------------- 0.3/1.0 MB 6.3 MB/s eta 0:00:01
#      ------------------------ --------------- 0.6/1.0 MB 6.4 MB/s eta 0:00:01
#      ------------------------------------ --- 0.9/1.0 MB 6.5 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.0 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pyparsing-3.0.9
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Jupyter notebook magic для отображения графиков прямо в блокноте (в питоновских скриптах графики по умолчанию строятся в отдельном окне):

# %%
# %matplotlib inline

# %% [markdown]
# ## Построение графика y(x) в одну строчку

# %% [markdown]
# Если у вас есть значения x и y:

# %%
x_values = [1, 3, 4, 7]
y_values = [2, 10, 17, 50]

# %% [markdown]
# Изобразить их на графике можно в одну строчку:

# %%
plt.plot(x_values, y_values)

# %% [markdown]
# Но чтобы настроить внешний вид графика, понадобится использовать дополнительные параметры функции plot() и, возможно, дописывать дополнительный код. Ниже мы познакомимся с некоторыми основными возможностями matplotlib.

# %% [markdown]
# ## Простой график

# %% [markdown]
# #### Генерируем набор данных

# %%
data = range(3, 10)
print(data)
# Out:
# range(3, 10)

# %% [markdown]
# #### Строим график с помощью команды plot

# %%
plt.plot(data)

# %%
import numpy as np

# %%
xx = np.arange(1.0, 5.0, 0.1)
yy = np.exp(xx)
plt.plot(xx, yy)

# %%
xx = np.linspace(1.0, 5.0, 25)
yy = np.exp(xx)
plt.plot(xx, yy)

# %% [markdown]
# ## Настройка внешнего вида графика

# %% [markdown]
# #### Тип и цвет линии

# %%
# ?plt.plot

# %%
plt.plot(yy, 'r')

# %%
plt.plot(data, color = 'red')

# %%
plt.plot(data, '^')

# %%
plt.plot(data, '--')

# %%
plt.plot(data, '*')

# %%
plt.plot(data, 'r*')

# %% [markdown]
# #### Задаем размер графика

# %%
plt.figure(figsize=(10, 6))
plt.plot(data)

# %% [markdown]
# #### Добавляем сетку

# %%
plt.figure(figsize=(10, 6))
plt.grid()
plt.plot(data)

# %% [markdown]
# #### Добавляем название графика

# %%
plt.title('Plot name')
plt.plot(data)

# %%
#не будет работать во втором Питоне
plt.title('Русскоязычное название')
plt.plot(yy)

# %%
# будет работать во втором Питоне
plt.title(u'Русскоязычное навзание', family="verdana")
plt.plot(data)

# %% [markdown]
# #### Подписи к осям

# %%
plt.title(u'Название', family='verdana')
plt.grid()
plt.xlabel(u'Ось x', family='verdana')
plt.ylabel(u'Ось y', family='verdana')
plt.plot(data)

# %% [markdown]
# #### Подписи на графике

# %%
plt.grid()
plt.title(u'Название', family='verdana')
plt.xlabel(u'Ось x', family='verdana')
plt.ylabel(u'Ось y', family='verdana')
plt.text(4.5, 4.1, u'Очень важный комментарий', family="verdana")
plt.text(4.5, 3.5, u'Еще один очень важный комментарий', family="verdana")
plt.plot(data)

# %% [markdown]
# ## Много графиков на одной плоскости

# %% [markdown]
# #### Сгенерируем данные

# %%
for i in range(10):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
linear = range(10)
nonlinear = [x ** 2 for x in range(10)]

# %%
nonlinear
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# #### Построим график

# %%
plt.grid()
plt.plot(linear, 'b-')
#plt.show()
plt.plot(nonlinear, 'g^')

# %% [markdown]
# #### Подписи к осям

# %%
# ?plt.scatter(6, 6)

# %%
plt.grid()
plt.plot(linear, 'b-')
plt.plot(nonlinear, 'g-')
plt.scatter(6, 6)
plt.legend(['linear', 'nonlinear'])

# %%
plt.grid()
plt.plot(linear, 'b--', label='linear')
plt.plot(nonlinear, 'g-', label='nonlinear')
plt.plot(yy[:10]**2, 'ro', label='exp')
#plt.scatter(6, 6)
plt.legend()

# %%
plt.grid()
plt.plot(linear, 'b-')
plt.plot(nonlinear, 'g-')
plt.legend(['linear', 'nonlinear'], loc=5)

# %% [markdown]
# ## Много графиков на одном изображении

# %%
plt.figure(figsize=(6, 4))

plt.subplot(211)
plt.grid()
plt.plot(linear, 'b-')

plt.subplot(212)
plt.grid()
plt.plot(nonlinear, 'g-')

# %%
# ?plt.subplot

# %% [markdown]
# ## Как сохранить график

# %%
plt.grid()
plt.plot(linear, 'b-')
plt.plot(nonlinear, 'r*')
plt.legend(['linear', 'nonlinear'], loc=2)
plt.xticks([0,3,8], [r'$\beta$',r'$\gamma$',r'$\alpha$'])
plt.title(r'$x=\frac{a}{b}$')
plt.savefig('../saved_plot.png', dpi=300)

# %% [markdown]
# Мы научились:
#    * Строить графики в matplotlib - команда plot();
#    * Настраивать внешний вид графика: сетка, подписи, несколько графиков;
#    * Сохранять полученные графики в виде изображения для дальнейшего использования.

# %% [markdown]
# # Что еще можно попробовать:

# %% [markdown]
# ### 3d графики
# http://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html#mplot3d-tutorial

# %% [markdown]
# ### "Живые" графики
# https://plot.ly/python/
