# %% [markdown]
# ## Exercise 1
# 1. Создайте график $x^2⋅sin(1/x^2)+x$ на интервале $[−1,1]$, используя 250 точек. Не забудьте пометить оси!
# 2. Создайте semilogy график (с логарифмической шкалой для оси y и линейной шкалой для оси x) относительной разницы  функций $1/(1+x^2)$ и $1/x^2$ на интервале $[5,25]$. (Относительная разница чисел $a$ и $b$ определяется как $|1−a/b|$)
# 3. В Scipy также есть много менее распространенных специальных функций. Взгляните на обширный список <a href=https://docs.scipy.org/doc/scipy/reference/special.html> здесь</a>! Выберите несколько интересных спец функций, которые вы знаете (или, может быть, не знаете), подставьте несколько чисел и начертите их.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy

# %%
xx = np.linspace(-1, 1, 250)
yy = xx ** 2 * np.sin(1 / xx ** 2) + xx
plt.plot(xx, yy)
plt.title('Task 1.1')
plt.xlabel(u'ОX', family='verdana')
plt.ylabel(u'ОY', family='verdana')
# Out:
# Text(0, 0.5, 'ОY')

# %%
xx = np.linspace(5, 25, 250)
y1 = 1 / (1 + xx ** 2)
y2 = 1 / xx ** 2
plt.semilogy(xx, abs(1 - y1 / y2))
plt.title('Task 1.2')
plt.xlabel(u'ОX', family='verdana')
plt.ylabel(u'Ln(ОY)', family='verdana')
# Out:
# Text(0, 0.5, 'Ln(ОY)')

# %%
xx = np.linspace(1, 5, 250)
y1 = scipy.special.log_ndtr(xx)
y2 = scipy.special.entr(xx)
y3 = scipy.special.y1(xx)
plt.plot(xx, y1, color = 'black', label = 'Logarithm of Gaussian cumulative distribution function')
plt.plot(xx, y2, color = 'yellow', label = 'Elementwise function for computing entropy')
plt.plot(xx, y3, color = 'green', label = 'Bessel function of the second kind of order 1')
plt.title('Task 1.3')
plt.xlabel(u'ОX', family='verdana')
plt.ylabel(u'ОY', family='verdana')
plt.legend()

# %% [markdown]
# ## Exercise 2
# 1. Построить график функции $sin(x)/x$ на отрезке $[-6\pi;6\pi]$ и добавить тики по оси $x$ с шагом $\pi/2$ от $-6\pi$ до $6\pi$, причём обозначения тиков должны содержать греческую букву $\pi$. Добавить сетку на график.

# %%
xx = np.linspace(-6 * np.pi, 6 * np.pi, 250)
yy = np.sin(xx) / xx
plt.figure(figsize=(15, 5))
plt.plot(xx, yy)
plt.xticks(np.arange(-6 * np.pi, 6.1 * np.pi, np.pi / 2), list(map(lambda x: x + "π", map(str, np.arange(-6, 6.1, 0.5)))))
plt.xlabel(u'ОX', family='verdana')
plt.ylabel(u'ОY', family='verdana')
plt.title('Task 2')
plt.grid()

# %% [markdown]
# ## Exercise 3
# 1. Создайте цветовой график $sin(x)sin(y)$ на интервале $[−π,π]×[−π,π]$.
# 2. Создайте цветовой график $e^{-x^2-y^2}$ на интервале $[−3,3]×[−3,3]$.

# %%
x = np.linspace(-np.pi, np.pi, 250)
y = np.linspace(-np.pi, np.pi, 250)
X, Y = np.meshgrid(x, y)

Z = np.sin(X) * np.sin(Y)
fig, ax = plt.subplots(figsize=(6,5))
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.pcolor(X, Y, Z, norm = norm, cmap="summer")
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])
plt.title('Task 3.1')
# Out:
# Text(0.5, 1.0, 'Task 3.1')

# %%
x = np.linspace(-3, 3, 250)
y = np.linspace(-3, 3, 250)
X, Y = np.meshgrid(x, y)

Z = np.exp(-X ** 2 - Y ** 2)
fig, ax = plt.subplots(figsize=(6,5))
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.pcolor(X, Y, Z, norm = norm, cmap="Pastel1")
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))

cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])
plt.title('Task 3.2')
# Out:
# Text(0.5, 1.0, 'Task 3.2')
